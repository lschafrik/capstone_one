# %% [markdown]
# - ### Remove NaN
#     - Create separate dataframe with NaN values
#         - Transform any necessary data
#         - Visualize null data

# %% [markdown]
# ![total_null.png](attachment:total_null.png)
# ![null_info.png](attachment:null_info.png)
# ![nan_general.png](attachment:nan_general.png)
# ![nan_describe_weight.png](attachment:nan_describe_weight.png)
# ![nan_describe_bust.png](attachment:nan_describe_bust.png)
# ![nan_describe_bodytype.png](attachment:nan_describe_bodytype.png)

# %% [markdown]
# - ### Clean data
#     - Transform any necessary data
#         - Weight from str(###lbs) to int(###)
#         - Height from str(#' ##") to float(##.##)
#         - Review Date to datetime
#     - Rename columns accordingly; changed spaces to underscores

# %% [markdown]
# ![Screen%20Shot%202020-01-06%20at%207.40.08%20PM.png](attachment:Screen%20Shot%202020-01-06%20at%207.40.08%20PM.png)
# ![Screen%20Shot%202020-01-06%20at%207.40.19%20PM.png](attachment:Screen%20Shot%202020-01-06%20at%207.40.19%20PM.png)
# ![Screen%20Shot%202020-01-06%20at%207.40.29%20PM.png](attachment:Screen%20Shot%202020-01-06%20at%207.40.29%20PM.png)
# ![Screen%20Shot%202020-01-06%20at%207.40.44%20PM.png](attachment:Screen%20Shot%202020-01-06%20at%207.40.44%20PM.png)
# ![dtypes_before.png](attachment:dtypes_before.png)
# ![dtypes_after.png](attachment:dtypes_after.png)
# ![Screen%20Shot%202020-01-08%20at%2011.24.02%20AM.png](attachment:Screen%20Shot%202020-01-08%20at%2011.24.02%20AM.png)

# %% [markdown]
# - ### Visualize general data

# %% [markdown]
# ![general_hist.png](attachment:general_hist.png)
# ![general_scatter.png](attachment:general_scatter.png)

# %% [markdown]
# - ### Visualize age data

# %% [markdown]
# ![age_info.png](attachment:age_info.png)
# ![age_fit.png](attachment:age_fit.png)
# ![download-4.png](attachment:download-4.png)
# ![Screen%20Shot%202020-01-07%20at%205.10.40%20PM.png](attachment:Screen%20Shot%202020-01-07%20at%205.10.40%20PM.png)
# ![Screen%20Shot%202020-01-07%20at%205.12.04%20PM.png](attachment:Screen%20Shot%202020-01-07%20at%205.12.04%20PM.png)
# ![download.png](attachment:download.png)
