# %%
import numpy as np
import scipy.stats as scs
import pandas as pd
import math
import matplotlib.pyplot as plt
import psycopg2 
import io
import sqlalchemy
# %matplotlib inline

# %%
rtr_data = pd.read_json('renttherunway_final_data.json', lines=True)

# %%
rtr_data.head()
# Out:
#    fit  user_id bust size  item_id  weight  rating     rented for  \
# 0  fit   420272       34d  2260466  137lbs    10.0       vacation
# 1  fit   273551       34b   153475  132lbs    10.0          other
# 2  fit   360448       NaN  1063761     NaN    10.0          party
# 3  fit   909926       34c   126335  135lbs     8.0  formal affair
# 4  fit   151944       34b   616682  145lbs    10.0        wedding
#
#                                          review_text          body type  \
# 0  An adorable romper! Belt and zipper were a lit...          hourglass
# 1  I rented this dress for a photo shoot. The the...  straight & narrow
# 2  This hugged in all the right places! It was a ...                NaN
# 3  I rented this for my company's black tie award...               pear
# 4  I have always been petite in my upper body and...           athletic
#
#                                       review_summary category height  size  \
# ...

# %%
rtr_data.count()
# Out:
# fit               192544
# user_id           192544
# bust size         174133
# item_id           192544
# weight            162562
# rating            192462
# rented for        192534
# review_text       192544
# body type         177907
# review_summary    192544
# category          192544
# height            191867
# size              192544
# age               191584
# review_date       192544
# dtype: int64

# %%
# bust size         174133
# weight            174133
# rating            174133
# rented for        192534
# body type         177907
# height            191867
# age               191584

nan_dict = {'bust_size': 174133, 'weight': 174133, 
            'rating': 174133, 'rented_for': 192534, 
            'body_type': 177907, 'height': 191867, 'age':191584}

# %%
print(max(nan_dict.items()), 192544-max(nan_dict.values()))
print(min(nan_dict.items()), 192544-min(nan_dict.values()))
# Out:
# ('weight', 174133) 10
# ('age', 191584) 18411

# %%
sorted(nan_dict.items())
# Out:
# [('age', 191584),
#  ('body_type', 177907),
#  ('bust_size', 174133),
#  ('height', 191867),
#  ('rating', 174133),
#  ('rented_for', 192534),
#  ('weight', 174133)]

# %%
type(rtr_data)
# Out:
# pandas.core.frame.DataFrame

# %%
nan_data = rtr_data[rtr_data.isnull().any(axis=1)]

# %%
print(nan_data.count())
nan_data.head()
# Out:
# fit               46163
# user_id           46163
# bust size         27752
# item_id           46163
# weight            16181
# rating            46081
# rented for        46153
# review_text       46163
# body type         31526
# review_summary    46163
# category          46163
# height            45486
# size              46163
# age               45203
# review_date       46163
# dtype: int64
#     fit  user_id bust size  item_id  weight  rating     rented for  \
# 2   fit   360448       NaN  1063761     NaN    10.0          party
# 8   fit   166228       36d  1729232     NaN    10.0  formal affair
# 22  fit   871659       36c  2736018     NaN    10.0           work
# 25  fit    85200      32dd   875667  140lbs     8.0          other
# 28  fit   205922       34b   149913     NaN     8.0          party
#
#                                           review_text          body type  \
# 2   This hugged in all the right places! It was a ...                NaN
# ...

# %%
nonan_data = rtr_data.dropna()

# %%
print(nonan_data.count())
nonan_data.head()
# Out:
# fit               146381
# user_id           146381
# bust size         146381
# item_id           146381
# weight            146381
# rating            146381
# rented for        146381
# review_text       146381
# body type         146381
# review_summary    146381
# category          146381
# height            146381
# size              146381
# age               146381
# review_date       146381
# dtype: int64
#    fit  user_id bust size  item_id  weight  rating     rented for  \
# 0  fit   420272       34d  2260466  137lbs    10.0       vacation
# 1  fit   273551       34b   153475  132lbs    10.0          other
# 3  fit   909926       34c   126335  135lbs     8.0  formal affair
# 4  fit   151944       34b   616682  145lbs    10.0        wedding
# 5  fit   734848       32b   364092  138lbs     8.0           date
#
#                                          review_text          body type  \
# 0  An adorable romper! Belt and zipper were a lit...          hourglass
# ...

# %%
conn = psycopg2.connect("dbname=lschafrik user=postgres")
cur = conn.cursor()

# %%
nonan_runway = nonan_data.to_sql(name='runway_users', con='')
# Out:
#   File "<ipython-input-29-42d39659ed79>", line 1
#     nonan_runway = nonan_data.to_sql(name='runway_users', con)
#                                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/2a/19/bee8cf05626674f892fc7745205ff010474cd523a23b555851ba4fa7bb5f/sql-0.4.0.tar.gz
# ...
#   Created wheel for sql: filename=sql-0.4.0-cp37-none-any.whl size=4113 sha256=ae535df89ba794aa375575b73f515c8a1fb37af8674f1db960464b86cdc97245
#   Stored in directory: /Users/lschafrik/Library/Caches/pip/wheels/1a/18/5a/3c918b3de538cabab699fe6a29e0361313bf5a2d7e0b82325a
# Successfully built sql
# ...
# Note: you may need to restart the kernel to use updated packages.
